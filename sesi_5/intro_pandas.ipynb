# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('nbaallelo.csv')
df.shape
# Out:
# (126314, 23)

# %%
# untuk melihat semua features dari Data Frame
pd.set_option("display.max.columns", None)
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.4149  1704.3949
# 126310         102            1     GSW   Warriors  104  1809.9791  1813.6349
# 126311         101            1     CLE  Cavaliers   91  1704.3949  1700.7391
# 126312         102            1     CLE  Cavaliers   97  1700.7391  1692.0859
# 126313         103            1     GSW   Warriors  105  1813.6349  1822.2881
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982    1495.236055    1495.236055
# std         0.244499      14.814845     112.139945     112.461687
# min         0.000000       0.000000    1091.644500    1085.774400
# ...

# %%
df['team_id'].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
df.value_counts('team_id').to_csv
# Out:
# <bound method NDFrame.to_csv of team_id
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# TRH      60
# DTF      60
# PIT      60
# INJ      60
# SDS      11
# Length: 104, dtype: int64>

# %%
df.value_counts('fran_id')
# Out:
# fran_id
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
df.loc[df['fran_id'] == 'Lakers', 'team_id'].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df['date_game'] = pd.to_datetime(df['date_game'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df['date_game'].head()
# Out:
# 0   1946-11-01
# 1   1946-11-01
# 2   1946-11-02
# 3   1946-11-02
# 4   1946-11-02
# Name: date_game, dtype: datetime64[ns]

# %%
df[df.date_game.dt.day == 2]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 2               2  194611020CHS   NBA        0     1947 1946-11-02
# 3               2  194611020CHS   NBA        1     1947 1946-11-02
# 4               3  194611020DTF   NBA        0     1947 1946-11-02
# 5               3  194611020DTF   NBA        1     1947 1946-11-02
# 6               4  194611020PRO   NBA        1     1947 1946-11-02
# ...           ...           ...   ...      ...      ...        ...
# 125939      62970  201504020DAL   NBA        1     2015 2015-04-02
# 125940      62971  201504020GSW   NBA        1     2015 2015-04-02
# 125941      62971  201504020GSW   NBA        0     2015 2015-04-02
# 126232      63117  201505020LAC   NBA        0     2015 2015-05-02
# 126233      63117  201505020LAC   NBA        1     2015 2015-05-02
#
#         seasongame  is_playoffs team_id   fran_id  pts      elo_i      elo_n  \
# 2                1            0     CHS     Stags   63  1300.0000  1309.6521
# ...

# %%
df.value_counts('team_id')
# Out:
# team_id
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# TRH      60
# DTF      60
# PIT      60
# INJ      60
# SDS      11
# Length: 104, dtype: int64

# %%
df.loc[df['team_id'] == 'BOS', 'fran_id'].value_counts()
# Out:
# Celtics    5997
# Name: fran_id, dtype: int64

# %%
df.loc[df['team_id'] == 'MNL', 'date_game'].min()
# Out:
# Timestamp('1948-11-04 00:00:00')

# %%
df.loc[df['team_id'] == 'MNL', 'date_game'].max()
# Out:
# Timestamp('1960-03-26 00:00:00')

# %%
df.loc[df['team_id'] == 'MNL', 'date_game'].agg(('min','max'))
# Out:
# min   1948-11-04
# max   1960-03-26
# Name: date_game, dtype: datetime64[ns]

# %%
df.loc[df['team_id'] == 'MNL', 'win_equiv'].agg(('min','max','mean','std'))
# Out:
# min     24.525501
# max     66.217308
# mean    45.702914
# std     10.443832
# Name: win_equiv, dtype: float64

# %%
data = [0.5,0,5,-2,0.2]

# %%
data
# Out:
# [0.5, 0, 5, -2, 0.2]

# %%
np.array(data)
# Out:
# array([ 0.5,  0. ,  5. , -2. ,  0.2])

# %%
ehehe = pd.Series(data)

# %%
ehehe
# Out:
# 0    0.5
# 1    0.0
# 2    5.0
# 3   -2.0
# 4    0.2
# dtype: float64

# %%
ehehe[2]
# Out:
# 5.0

# %%
pd.Series(data).values
# Out:
# array([ 0.5,  0. ,  5. , -2. ,  0.2])

# %%
pd.Series(data).index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
pd.Series(data, index=['a','b','c','d','e'])
# Out:
# a    0.5
# b    0.0
# c    5.0
# d   -2.0
# e    0.2
# dtype: float64

# %%
my_dict = {'kaset':100000,
            'CD':50000,
            'DVD':200000}

ser_dict = pd.Series(my_dict)
ser_dict
# Out:
# kaset    100000
# CD        50000
# DVD      200000
# dtype: int64

# %%
# dataframe
nilai = [[76,80,77,90],
         [90,85,60,70],
         [88,89,78,90],
         [68,50,70,40]] #matematika, IPA, bahasa Indo, bahasa Ing

df = pd.DataFrame(nilai, 
                  columns=['matematika','ipa','bahasa_indonesia','bahasa_inggris'], 
                  index=['Budi','Danu','Eka','Wendi'])
df
# Out:
#        matematika  ipa  bahasa_indonesia  bahasa_inggris
# Budi           76   80                77              90
# Danu           90   85                60              70
# Eka            88   89                78              90
# Wendi          68   50                70              40

# %%
df['ipa']
# Out:
# Budi     80
# Danu     85
# Eka      89
# Wendi    50
# Name: ipa, dtype: int64

# %%
df['matematika']['Budi']
# Out:
# 76

# %%
df.loc['Budi','ipa']
# Out:
# 80

# %%
df.loc['Budi',:]
# Out:
# matematika          76
# ipa                 80
# bahasa_indonesia    77
# bahasa_inggris      90
# Name: Budi, dtype: int64

# %%
# loc & iloc
ser_data_idx = pd.Series(data, index=['a','b','c','d','e'])

# %%
# menggunakan loc
ser_data_idx
# Out:
# a    0.5
# b    0.0
# c    5.0
# d   -2.0
# e    0.2
# dtype: float64

# %%
ser_data_idx.loc['c']
# Out:
# 5.0

# %%
ser_data_idx.loc['a':'c']
# Out:
# a    0.5
# b    0.0
# c    5.0
# dtype: float64

# %%
# menggunakan iloc
ser_data_idx.iloc[2]
# Out:
# 5.0

# %%
ser_data_idx.iloc[0:2]
# Out:
# a    0.5
# b    0.0
# dtype: float64

# %%
nilai = [[76,80,77,90],
         [90,85,60,70],
         [88,89,78,90],
         [68,50,70,40]] #matematika, IPA, bahasa Indo, bahasa Ing

df = pd.DataFrame(nilai, 
                  columns=['matematika','ipa','bahasa_indonesia','bahasa_inggris'], 
                  index=['Budi','Danu','Eka','Wendi'])
df
# Out:
#        matematika  ipa  bahasa_indonesia  bahasa_inggris
# Budi           76   80                77              90
# Danu           90   85                60              70
# Eka            88   89                78              90
# Wendi          68   50                70              40

# %%
df.loc['Budi':'Eka', 'ipa':'bahasa_inggris']
# Out:
#       ipa  bahasa_indonesia  bahasa_inggris
# Budi   80                77              90
# Danu   85                60              70
# Eka    89                78              90

# %% [markdown]
# ## Query

# %%
df = pd.read_csv('nbaallelo.csv')
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
# query -> kondisi
df[df['pts'] > 60]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 11              6  194611030CLR   NBA        0     1947  11/3/1946
# 13              7  194611040PIT   NBA        1     1947  11/4/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
kondisi = df['year_id'] > 2010
df_curr_decade = df[kondisi]

# %%
df_curr_decade
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df[df['notes'].notnull()]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts      elo_i  \
# 930             28            0     WSC      Capitols   71  1469.3469
# ...

# %%
df['fran_id'].str.endswith("ers")
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 126309     True
# 126310    False
# 126311     True
# 126312     True
# 126313    False
# Name: fran_id, Length: 126314, dtype: bool

# %%
kondisi = df['fran_id'].str.endswith("ers")
df[kondisi]['fran_id'].value_counts()
# Out:
# Lakers          6024
# Sixers          5644
# Pacers          4227
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Bombers          249
# Steamrollers     168
# Packers           72
# Name: fran_id, dtype: int64

# %%
kondisi1 = df['fran_id'] == 'Spurs'
kondisi2 = df['year_id'] > 2010

df[kondisi & kondisi2]['game_result'].value_counts()
# Out:
# L    1296
# W    1251
# Name: game_result, dtype: int64

# %%
df[kondisi1 & kondisi2].groupby(['year_id','game_result'])['game_id'].count()
# Out:
# year_id  game_result
# 2011     L              25
#          W              63
# 2012     L              20
#          W              60
# 2013     L              30
#          W              73
# 2014     L              27
#          W              78
# 2015     L              31
#          W              58
# Name: game_id, dtype: int64
